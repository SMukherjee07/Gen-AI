# %%
# %pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.insert(0, './scripts')
from snowflakeDbConnector import SnowflakeDbConnector
# Out:
# /Users/samanwitamukherjee/anaconda3/lib/python3.11/site-packages/snowflake/connector/options.py:108: UserWarning: You have an incompatible version of 'pyarrow' installed (11.0.0), please install a version that adheres to: 'pyarrow<10.1.0,>=10.0.1; extra == "pandas"'
#   warn_incompatible_dep(

# %%
client='wahoofitnessca'
snowflake_db_connector = SnowflakeDbConnector()
database_query = f'''
      USE DATABASE brands_{client};
      '''
_= snowflake_db_connector.getResultForQuery(database_query)

# %%
dataframe_query='''select asin,product_title from aramus.product_catalog
where (asin,feed_date) In (select asin,max(feed_date) from aramus.product_catalog group by 1);'''

# %%
df= snowflake_db_connector.getResultForQuery(dataframe_query)

# %%
df
# Out:
#           ASIN                                      PRODUCT_TITLE
# 0   B01K6P748E  Wahoo KICKR Multi-Purpose, Adjustable Height D...
# 1   B00O5Y4FXA  Wahoo TICKR X Heart Rate Monitor with Memory, ...
# 2   B01DFQUTTC                     Wahoo ELEMNT GPS Bike Computer
# 3   B01DIE7LUG                     Wahoo RPM Cycling Speed Sensor
# 4   B00L9XNFPY  Wahoo RPM Cadence Sensor for iPhone, Android a...
# 5   B00NW882KM  Wahoo Blue SC Cycling Speed and Cadence Sensor...
# 6   B0042WGO3Y         Wahoo ANT+ Adapter Key for iPod and iPhone
# 7   B00INQVYZ8     Wahoo TICKR Heart Rate Monitor, Bluetooth/ANT+
# 8   B00PD9GHUA  Wahoo KICKR Multi-Purpose Floor Mat for Indoor...
# 9   B01E0YRQIA           Wahoo RPM Cycling Speed & Cadence Sensor
# 10  B0741JGHB5                    Wahoo ELEMNT Mini Bike Computer
# 11  B0071ICZPM  Wahoo Protector Bike Case for iPhone 3G, 3GS, ...
# 12  B004V38BW6  Wahoo Extended Battery for Wahoo Bike Case or ...
# ...

# %%
import requests
import json
import openai
API_KEY = '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'
API_ENDPOINT = "https://api.openai.com/v1/chat/completions"

def generate_chat_completion(messages, model="gpt-4", temperature=1, max_tokens=None):
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {API_KEY}",
    }

    data = {
        "model": model,
        "messages": messages,
        "temperature": temperature,
    }

    if max_tokens is not None:
        data["max_tokens"] = max_tokens

    response = requests.post(API_ENDPOINT, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        return response.json()["choices"][0]["message"]["content"]
    else:
        raise Exception(f"Error {response.status_code}: {response.text}")

# %%
response_dict = {}
for i in df.index :
    PRODUCT_TITLE = df.loc[i,'PRODUCT_TITLE']
    ASIN = df.loc[i,'ASIN']

    messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": f'''This is my product title : {PRODUCT_TITLE}
    which I sell on amazon.ca can you help me with 100 search terms where ~60% generic, 20% client branded,
    20% competitor branded search terms
    which are very relevant to my product, also can you put it in a dictionary with client, comp and generic as keys for me,
    can you send me the required data as a dictionary such that this output starts after 'ABC' and ends before 'XYZ'and the product_title starts before'$'and ends before'$'
    output should be of the format:
    ${PRODUCT_TITLE}$
    'ABC'
    'generic':[]
    'client':[]
    'comp':[]
    'XYZ'
    '''}
    ]
    response_text = generate_chat_completion(messages)
    print(response_text)
    response_dict[ASIN] = response_text
# Out:
# Sure, here is your dictionary with generic, client and competitor branded search terms for the product 'Wahoo KICKR Multi-Purpose, Adjustable Height Desk for Indoor Cycling and Standing' relevant to Amazon.ca marketplace:
#
# $Wahoo KICKR Multi-Purpose, Adjustable Height Desk for Indoor Cycling and Standing$
# 'ABC'
# {
# ...

# %%
tot=len(response_dict.keys())
tot
# Out:
# 30

# %%
response_dict
# Out:
# {'B01K6P748E': "Sure, here is your dictionary with generic, client and competitor branded search terms for the product 'Wahoo KICKR Multi-Purpose, Adjustable Height Desk for Indoor Cycling and Standing' relevant to Amazon.ca marketplace:\n\n$Wahoo KICKR Multi-Purpose, Adjustable Height Desk for Indoor Cycling and Standing$\n'ABC'\n{\n 'generic': ['Adjustable desk', 'Multi-purpose desk', 'Desk for cycling', 'Indoor cycling desk', 'Standing desk', 'Exercise desk', 'Fitness desk', 'Workout desk', 'Ergonomic desk', 'Home office desk', 'Health desk', 'Active desk', 'Versatile desk', 'Home gym equipment', 'Indoor exercise equipment', 'Height Adjustable desk', 'Exercise equipment', 'Fitness equipment', 'Indoor fitness desk', 'Training desk', 'Cycling accessory', 'Active workspace', 'Indoor bike desk', 'Bike workstation', 'Stand up desk', 'Office gym equipment', 'Biking desk', 'Pedal desk', 'Bicycle desk', 'Cycling exercise desk', 'Fitness workout desk', 'Adjustable height desk', 'Work from 
# ...

# %%
import re
import csv


table = []
count=0
for asin in df['ASIN']:
    if asin in response_dict:
        count=count+1
        content = response_dict[asin]
        keyword_data = re.search(r"'ABC'(.*?)'XYZ'", content, re.DOTALL).group(1)

        keyword_matches = re.finditer(r"'([a-z]+)':\s*\[([^\]]+)]", keyword_data)

        for keyword_match in keyword_matches:
            keyword_type = keyword_match.group(1)
            keywords_raw = keyword_match.group(2)
            keywords = re.findall(r"'([^']*)'", keywords_raw)  # Extract keywords even if separated by '\n'

            for keyword in keywords:
                if keyword:  # Check if the keyword is not empty
                    keyword=keyword.lower()
                    table.append([asin, keyword_type, keyword])

# Save the resulting table to a CSV file
csv_file = "keyword_table.csv"
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["ASIN", "Keyword Type", "Keyword"])
    writer.writerows(table)

print(count)
success_index=(count/tot)*100
print("successIndex:")
print(success_index)
# Print the resulting table
print("ASIN\t\tKeyword Type\tKeyword")
for row in table:
    print(f"{row[0]}\t{row[1]}\t\t{row[2]}")

print(f"Data saved to '{csv_file}'")
# Out:
# 30
# successIndex:
# 100.0
# ASIN		Keyword Type	Keyword
# B01K6P748E	generic		adjustable desk
# B01K6P748E	generic		multi-purpose desk
# B01K6P748E	generic		desk for cycling
# B01K6P748E	generic		indoor cycling desk
# B01K6P748E	generic		standing desk
# B01K6P748E	generic		exercise desk
# B01K6P748E	generic		fitness desk
# B01K6P748E	generic		workout desk
# B01K6P748E	generic		ergonomic desk
# B01K6P748E	generic		home office desk
# B01K6P748E	generic		health desk
# B01K6P748E	generic		active desk
# B01K6P748E	generic		versatile desk
# B01K6P748E	generic		home gym equipment
# B01K6P748E	generic		indoor exercise equipment
# B01K6P748E	generic		height adjustable desk
# B01K6P748E	generic		exercise equipment
# B01K6P748E	generic		fitness equipment
# B01K6P748E	generic		indoor fitness desk
# B01K6P748E	generic		training desk
# B01K6P748E	generic		cycling accessory
# B01K6P748E	generic		active workspace
# B01K6P748E	generic		indoor bike desk
# B01K6P748E	generic		bike workstation
# ...

# %%
from collections import Counter
from tabulate import tabulate
import csv
# Count the occurrences of each keyword and keyword type across recommendations for different ASINs
keyword_counter = Counter((row[2], row[1]) for row in table)

# Create a list of tuples where each tuple contains (keyword, keyword_type, count)
keyword_frequency_list = [(keyword_type, keyword, count) for (keyword, keyword_type), count in keyword_counter.items()]

# Sort the list in descending order based on the count
sorted_keyword_frequency = sorted(keyword_frequency_list, key=lambda x: x[2], reverse=True)

# Select the top 10,000 rows
top_keywords = sorted_keyword_frequency[:10000]


# Specify the filename for the CSV file
csv_filename = 'top_keywords.csv'

# Write the top_keywords list to a CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Keyword Type', 'Keyword', 'Count'])

    # Write the data rows
    for keyword_type, keyword, count in top_keywords:
        csv_writer.writerow([keyword_type, keyword, count])

print(f"CSV file '{csv_filename}' has been created.")
# Convert DataFrame to a table
top_1000 = tabulate(top_keywords, headers='keys', tablefmt='grid')

# Print the table
print(top_1000)
# Out:
# CSV file 'top_keywords.csv' has been created.
# +---------+----------------------------------------+-----+
# | 0       | 1                                      |   2 |
# +=========+========================================+=====+
# | client  | wahoo fitness tracker                  |  10 |
# +---------+----------------------------------------+-----+
# | generic | exercise equipment                     |   8 |
# +---------+----------------------------------------+-----+
# | generic | cycling equipment                      |   8 |
# +---------+----------------------------------------+-----+
# | generic | cycling gear                           |   8 |
# +---------+----------------------------------------+-----+
# | generic | fitness equipment                      |   7 |
# +---------+----------------------------------------+-----+
# | generic | cycling accessory                      |   6 |
# +---------+----------------------------------------+-----+
# ...

# %%
import csv
from collections import Counter
from tabulate import tabulate

table = [(keyword.lower(), keyword_type, count) for keyword, keyword_type, count in table]


keyword_counter = Counter((row[2], row[1]) for row in table)

keyword_frequency_list = [(keyword_type, keyword, count) for (keyword, keyword_type), count in keyword_counter.items()]

sorted_keyword_frequency = sorted(keyword_frequency_list, key=lambda x: x[2], reverse=True)

top_keywords = sorted_keyword_frequency[:10000]

csv_filename = 'top_keywords.csv'

with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Keyword Type', 'Keyword', 'Count'])
    for keyword_type, keyword, count in top_keywords:
        csv_writer.writerow([keyword_type, keyword, count])

print(f"CSV file '{csv_filename}' has been created.")

# Convert the list to a list of dictionaries for tabulate
top_keywords_dict_list = [{"Keyword Type": keyword_type, "Keyword": keyword, "Count": count} for keyword_type, keyword, count in top_keywords]

top_1000 = tabulate(top_keywords_dict_list, headers="keys", tablefmt="grid")
print(top_1000)
# Out:
# CSV file 'top_keywords.csv' has been created.
# +----------------+----------------------------------------+---------+
# | Keyword Type   | Keyword                                |   Count |
# +================+========================================+=========+
# | client         | wahoo fitness tracker                  |      10 |
# +----------------+----------------------------------------+---------+
# | generic        | exercise equipment                     |       8 |
# +----------------+----------------------------------------+---------+
# | generic        | cycling equipment                      |       8 |
# +----------------+----------------------------------------+---------+
# | generic        | cycling gear                           |       8 |
# +----------------+----------------------------------------+---------+
# | generic        | fitness equipment                      |       7 |
# +----------------+----------------------------------------+---------+
# ...
